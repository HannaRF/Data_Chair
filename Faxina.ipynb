# %%
import pandas as pd

# %%
dados = pd.read_excel('dados de todas as redes.xlsx',sheet_name='tudo')
dados
# Out:
#     Chain         Category                         Item Serving Size  \
# 0      BK          WHOPPER                     WHOPPER®        361 g
# 1      BK          WHOPPER               WHOPPER® Duplo        456 g
# 2      BK          WHOPPER             WHOPPER® Furioso        386 g
# 3      BK          WHOPPER                 WHOPPER Jr.®        196 g
# 4      BK          WHOPPER  WHOPPER Jr.® Barbecue Bacon        249 g
# ..    ...              ...                          ...          ...
# 956    SB  Others Beverage                Mocha Drizzle          NaN
# 957    SB  Others Beverage              Caramel Drizzle          NaN
# 958    SB  Others Beverage                Espresso Shot       1 shot
# 959    SB  Others Beverage      Matcha Green Tea Powder      1 scoop
# 960    SB  Others Beverage       Protein & Fibre Powder      1 scoop
#
#       Calories  Total Fat Saturated Fat Trans Fat Cholesterol       Sodium  \
# ...

# %%
local = pd.read_excel('localização.xlsx')
local
# Out:
#                                                Address          City  \
# 0             900 W Greenwood St, Abbeville, SC, 29620     Abbeville
# 1             1021 Church Point Road, Rayne, LA, 70578         Rayne
# 2      2601 North Parkerson Avenue, Crowley, LA, 70526       Crowley
# 3                 8378 W Overland Rd, Boise, ID, 83709         Boise
# 4                          6770 Glenwood Street, Boise         Boise
# ...                                                ...           ...
# 17031                                     554 N 3rd St       Laramie
# 17032                                    3112 E. Grand       Laramie
# 17033                                   3021 Grand Ave       Laramie
# 17034                                 118 Westland Way  Rock Springs
# 17035                                 2208 Coffeen Ave     Sheridian
#
#       State/Province  Post Code           Phone     Provider Country
# 0                 SC      29620    864-366-2099  Burger King     USA
# ...

# %%
dados.isnull().sum() #procurando valores nulos
# Out:
# Chain                        0
# Category                     0
# Item                         0
# Serving Size                 2
# Calories                     0
# Total Fat                    0
# Saturated Fat                0
# Trans Fat                    0
# Cholesterol                  0
# Sodium                       0
# Carbohydrates                0
# Dietary Fiber                0
# Sugars                       0
# Protein                      0
# Vitamin A (% Daily Value)    0
# Vitamin C (% Daily Value)    0
# Calcium (% Daily Value)      0
# Iron (% Daily Value)         0
# Salt                         0
# Caffeine                     0
# dtype: int64

# %%
local.isnull().sum()
# Out:
# Address           2
# City              1
# State/Province    0
# Post Code         1
# Phone             0
# Provider          0
# Country           0
# dtype: int64

# %%
dados.dropna(inplace=True) 
local.dropna(inplace=True)
# o default é inplace=False , fazendo com que os valores nulos só sejam deletados na visualização do Data Frame
